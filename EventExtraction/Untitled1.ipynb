# %%
import nltk
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_db():
    client = MongoClient()
    return client.twitter

# %%
db = get_db()
collection=[i for i in db.refined.find()]

# %%
text = pd.DataFrame([i['text'] for i in collection])
popularity = pd.DataFrame([i['popularity'] for i in collection])
demo = pd.DataFrame([i['demographics'] for i in collection])

# %%
text.head(200)
# Out:
#     classification  polarity  subjectivity  \
# 0              pos  0.833333      0.166667
# 1              neg  0.274824      0.725176
# 2              pos  0.702646      0.297354
# 3              pos  0.865379      0.134621
# 4              pos  0.888409      0.111591
# 5              pos  0.997063      0.002937
# 6              pos  0.976679      0.023321
# 7              pos  0.823695      0.176305
# 8              pos  0.861195      0.138805
# 9              pos  0.500000      0.500000
# 10             pos  0.882276      0.117724
# 11             pos  0.866747      0.133253
# 12             pos  0.565574      0.434426
# 13             neg  0.045562      0.954438
# 14             pos  0.933710      0.066290
# 15             pos  0.632129      0.367871
# 16             pos  0.759948      0.240052
# 17             pos  0.998499      0.001501
# 18             neg  0.090876      0.909124
# 19             pos  0.500000      0.500000
# 20             pos  0.946976      0.053024
# ...

# %%
plt.plot(text.tweet_lenght)
